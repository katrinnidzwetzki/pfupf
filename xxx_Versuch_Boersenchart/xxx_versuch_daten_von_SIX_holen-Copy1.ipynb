# %% [markdown]
# # Versuch mit Six-Website

# %% [markdown]
# https://www.six-group.com/exchanges/indices/security_info_de.html?id=CH0009987501CHF9

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time
import pandas as pd
from bs4 import BeautifulSoup
import random

# %%
# Generated by Selenium IDE
import pytest
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from time import sleep
driver = webdriver.Chrome(executable_path='/usr/bin/chromedriver')
driver.get("https://www.six-group.com/exchanges/indices/security_info_de.html?id=CH0009987501CHF9")
sleep(2)
driver.set_window_size(1920, 1016)
driver.find_element(By.ID, "swx_widget__ImageTabButton_2").click()
sleep(2)
driver.find_element_by_id('swx_widget__ImageTabButton_6').click()
sleep(2)
element = driver.find_element(By.ID, "tabs_level2_3_tablist")
actions = ActionChains(driver)
actions.move_to_element(element).perform()
sleep(2)
element = driver.find_element(By.CSS_SELECTOR, "body")
actions = ActionChains(driver)
actions.move_to_element(element).perform()
driver.find_element(By.NAME, "actionSUBMIT").click()

# %% [markdown]
# csv-datei landet im download-folder

# %%
#datei einlesen
#downloadpath = "8888/notebooks/Downloads/info_market_data_download.csv"
#downloadpath = "localhost:8888/tree/Downloads/info_market_data_download.csv"
downloadpath = "/home/pc/Downloads/info_market_data_download.csv"

# %%
pd.set_option('display.max_rows', None)
df = pd.read_csv(downloadpath, encoding= 'unicode_escape')

# %%
df.head(62)
# Out:
#          SPI® TR (SXGE/CH0009987501)
# 0                        17.03.2020;
# 1                 Date;Price;Volume;
# 2             17.03.2020;10301.48;0;
# 3             16.03.2020;10029.88;0;
# 4             13.03.2020;10227.06;0;
# 5             12.03.2020;10144.29;0;
# 6             11.03.2020;11161.17;0;
# 7             10.03.2020;11227.97;0;
# 8             09.03.2020;11248.96;0;
# 9             06.03.2020;11880.22;0;
# 10            05.03.2020;12347.87;0;
# 11            04.03.2020;12482.78;0;
# 12            03.03.2020;12300.34;0;
# 13            02.03.2020;12046.83;0;
# 14            28.02.2020;11897.75;0;
# 15            27.02.2020;12341.04;0;
# 16            26.02.2020;12703.63;0;
# 17            25.02.2020;12670.86;0;
# 18            24.02.2020;12926.59;0;
# 19            21.02.2020;13400.18;0;
# 20            20.02.2020;13453.31;0;
# 21            19.02.2020;13561.17;0;
# 22            18.02.2020;13424.11;0;
# 23            17.02.2020;13457.28;0;
# 24            14.02.2020;13419.95;0;
# 25            13.02.2020;13356.42;0;
# 26            12.02.2020;13373.62;0;
# 27            11.02.2020;13397.54;0;
# 28            10.02.2020;13331.64;0;
# 29            07.02.2020;13280.42;0;
# 30            06.02.2020;13297.95;0;
# 31            05.02.2020;13284.03;0;
# 32            04.02.2020;13077.32;0;
# 33             03.02.2020;12916.3;0;
# 34            31.01.2020;12870.99;0;
# 35            30.01.2020;13013.22;0;
# 36            29.01.2020;13150.38;0;
# 37             28.01.2020;13055.3;0;
# 38            27.01.2020;12940.79;0;
# 39            24.01.2020;13149.91;0;
# 40            23.01.2020;13104.33;0;
# 41            22.01.2020;13211.52;0;
# 42            21.01.2020;13194.07;0;
# 43            20.01.2020;13134.37;0;
# 44            17.01.2020;13117.25;0;
# 45            16.01.2020;12947.78;0;
# 46            15.01.2020;12914.36;0;
# 47            14.01.2020;12894.36;0;
# 48             13.01.2020;12857.7;0;
# 49             10.01.2020;12866.5;0;
# 50            09.01.2020;12880.66;0;
# 51            08.01.2020;12879.51;0;
# 52            07.01.2020;12924.74;0;
# 53             06.01.2020;12899.7;0;
# 54            03.01.2020;12938.67;0;
# 55             30.12.2019;12837.5;0;
# 56            27.12.2019;12972.24;0;
# 57            23.12.2019;12957.44;0;
# 58            20.12.2019;12895.69;0;
# 59            19.12.2019;12767.23;0;
# 60            18.12.2019;12748.55;0;
# 61            17.12.2019;12734.78;0;

# %%
##index nur werte, xxx Zeilen (handelstage)
