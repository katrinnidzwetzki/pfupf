# %% [markdown]
# # Versuch mit Six-Website

# %% [markdown]
# https://www.six-group.com/exchanges/indices/security_info_de.html?id=CH0009987501CHF9

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time
import pandas as pd
from bs4 import BeautifulSoup
import random
import numpy as np
import re
import glob

# %%
# Generated by Selenium IDE
import pytest
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from time import sleep
driver = webdriver.Chrome(executable_path='/usr/bin/chromedriver')
driver.get("https://www.six-group.com/exchanges/indices/security_info_de.html?id=CH0009987501CHF9")
sleep(2)
driver.set_window_size(1920, 1016)
driver.find_element(By.ID, "swx_widget__ImageTabButton_2").click()
sleep(2)
driver.find_element_by_id('swx_widget__ImageTabButton_6').click()
sleep(2)
element = driver.find_element(By.ID, "tabs_level2_3_tablist")
actions = ActionChains(driver)
actions.move_to_element(element).perform()
sleep(2)
element = driver.find_element(By.CSS_SELECTOR, "body")
actions = ActionChains(driver)
actions.move_to_element(element).perform()
driver.find_element(By.NAME, "actionSUBMIT").click()

# %% [markdown]
# csv-datei landet im download-folder, den weg kann ich nicht nachvollziehen

# %% [markdown]
# datei einlesen

# %%
#pd.set_option('display.max_rows', None)

#df = pd.read_csv("/home/pc/Downloads/info_market_data_download.csv", encoding= 'unicode_escape', sep=';')

#df = pd.read_csv("/home/pc/Downloads/info_market_data_download.csv", sep='delimeter', encoding= 'unicode_escape', header=None, skiprows=2)

df = pd.read_csv("/home/pc/Downloads/info_market_data_download.csv", encoding= 'unicode_escape', skiprows=2, sep=';')

# %%
#df = df.convert_objects(convert_numeric=True)

# %%
df.dtypes    ## output: die spalte 'date' ist nicht sauber formatiert
# Out:
#         Date     object
# Price           float64
# Volume            int64
# Unnamed: 3      float64
# dtype: object

# %%
df.head(5)
# Out:
#                    Date     Price  Volume  Unnamed: 3
# 0            19.03.2020  10407.20       0         NaN
# 1            18.03.2020  10129.06       0         NaN
# 2            17.03.2020  10296.23       0         NaN
# 3            16.03.2020  10029.88       0         NaN
# 4            13.03.2020  10227.06       0         NaN

# %%
df = df.iloc[:60]    ##zeilen herausfiltern
df
# Out:
#                     Date     Price  Volume  Unnamed: 3
# 0             19.03.2020  10407.20       0         NaN
# 1             18.03.2020  10129.06       0         NaN
# 2             17.03.2020  10296.23       0         NaN
# 3             16.03.2020  10029.88       0         NaN
# 4             13.03.2020  10227.06       0         NaN
# 5             12.03.2020  10144.29       0         NaN
# 6             11.03.2020  11161.17       0         NaN
# 7             10.03.2020  11227.97       0         NaN
# 8             09.03.2020  11248.96       0         NaN
# 9             06.03.2020  11880.22       0         NaN
# 10            05.03.2020  12347.87       0         NaN
# 11            04.03.2020  12482.78       0         NaN
# 12            03.03.2020  12300.34       0         NaN
# 13            02.03.2020  12046.83       0         NaN
# 14            28.02.2020  11897.75       0         NaN
# 15            27.02.2020  12341.04       0         NaN
# ...

# %%
header = ["Date", "Price"]
df.to_csv('daten_3_monate.csv', encoding='utf-8', index=False, columns = header)

## Der Inhalt von 'Date' wird nicht gespeichert
# Out:
# /home/pc/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
#df['Date']   #funktioniert nicht

# %%
#df['Date'] = pd.to_datetime(df['Date'], format= '%d/%m/%Y')

# %%
#df.iloc() = df.iloc().astype(float)
